# %% [markdown]
# # Python Packages Used

# %% [markdown]
# ![logo](img/logos.svg)
#
# *v.0.1 05/05/2022*

# %% [markdown]
# <!--NAVIGATION-->
# <span style='background: rgb(128, 128, 128, .15); width: 100%; display: block; padding: 10px 0 10px 10px'>| [Welcome](00.00-Welcome.ipynb) ></span>
#
# <a href="https://colab.research.google.com/github/eurostat/e-learning/blob/main/python-official-statistics/07.02-All-Packages.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>

# %% [markdown]
# ## Table of Contents
#
# ### [By Chapter](#chapter)
# ### [Alphabetically](#alpha)

# %% [markdown]
# <a id='chapter'></a>
#
#
# ## By Chapter
# Here there are mentioned just the packages explicitly imported for code.
#
# ### 1. The Python's World
# - Hello World!
# ```python
# import random as rnd
# import numpy
# import warnings
# ```
# <br><br>
#
# ### 2. A little bit of Python’s kitchen
# - Flow Control & Functions
# ```python
# import random
# ```
# <br><br>
#
# ### 3. Performance computing
# - Numpy & Data Types
# ```python
# import array
# import numpy as np
# ```
# - More functionality: SciPy
# ```python
# from numpy import *
# from numpy.random import rand, randn
# from numpy.fft import fft, ifft
# from numpy.lib.scimath import *
# import numpy, scipy
# ```
# - More speed: Numba & Cython
# ```python
# import numpy
# from numba import double, jit
# ```
# <br><br>
#
# ### 4. pandas - Python Data Analysis Library
# - Series & Dataframes
# ```python
# import numpy as np
# import pandas as pd
# ```
# - Advanced Processing
# ```python
# import pandas as pd
# import numpy as np
# import sqlite3
# import pandas_datareader.data as web
# import seaborn as sns
# import datetime
# ```
# <br><br>
#
# ### 5. Visualization with Python
# - Matplotlib
# ```python
# import matplotlib as mpl
# import matplotlib.pyplot as plt
# import numpy as np
# from IPython.display import Image
# import numpy as np
# ```
# - Evolutions: Seaborn, Plotly and Bokeh
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# import seaborn as sns
# import plotly.express as px
# import plotly.express as px
# from bokeh.plotting import figure, show
# from bokeh.io import output_notebook
# from bokeh.transform import factor_cmap, factor_mark
# from bokeh.layouts import gridplot
# from bokeh.palettes import Category10
# ```
# <br><br>
#
# ### 6. Machine Learning Frameworks in Python
# - Scikit-learn
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
# from sklearn.linear_model import LinearRegression
# import seaborn as sns
# from sklearn.model_selection import train_test_split
# from sklearn.naive_bayes import GaussianNB
# from sklearn.metrics import accuracy_score
# from sklearn.decomposition import PCA
# from sklearn.mixture import GaussianMixture
# import matplotlib.pyplot as plt
# from sklearn.datasets import fetch_openml
# from sklearn.neural_network import MLPClassifier
# from sklearn.model_selection import train_test_split
# ```
# - Tensorflow + Keras and PyTorch
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
# import tensorflow as tf
# import matplotlib.pyplot as plt
# from sklearn.datasets import fetch_openml
# from sklearn.model_selection import train_test_split
# from tensorflow import keras
# from keras import layers
# from keras.utils import np_utils
# from keras import callbacks
# import pandas as pd
# import random
# import numpy as np
# from keras.datasets import mnist
# import torch
# import torchvision as tv
# import torch.nn as nn
# import torch.nn.functional as F
# from torch import optim
# import tensorflow_hub as hub
# ```

# %% [markdown]
# <a id='alpha'></a>
#
#
# ## Alphabetically
#
# - python (v. 3.8.8)
# packages included in python distribution:
# >- array
# >- datetime
# >- random
# >- sqlite3
# >- warnings
#
#
# - bokeh (v. 2.3.2)
#
# - IPython (v. 7.32.0)
#
# - keras (v. 2.8.0)
#
# - matplotlib (v. 3.3.4)
#
# - numpy (v. 1.20.0)
# - numba (v. 0.53.1)
#
# - pandas (v. 1.4.1)
# - plotly (v. 4.14.3)
#
# - scipy (v. 1.6.2)
# - seaborn (v. 0.11.1)
# - sklearn (v. 0.24.1)
#
# - tensorflow (v. 2.8.0)
# - torch (v. 1.11.0+cpu)
# - torchvision (v. 0.12.0+cpu)
# - tensorflow_hub (v. 0.12.0)

# %% [markdown]
# <span style='background: rgb(128, 128, 128, .15); width: 100%; display: block; padding: 10px 0 10px 10px'>This is the Jupyter notebook version of the __Python for Official Statistics__ produced by Eurostat; the content is available [on GitHub](https://github.com/eurostat/e-learning/tree/main/python-official-statistics).
# <br>The text and code are released under the [EUPL-1.2 license](https://github.com/eurostat/e-learning/blob/main/LICENSE).</span>
